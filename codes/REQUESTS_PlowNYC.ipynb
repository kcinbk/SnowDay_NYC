# %%
import subprocess

result = subprocess.run(
    ["pip", "install", "git+https://github.com/kcinbk/get_opendata.git"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL,
)

if result.returncode == 0:
    print("Module installed")
else:
    raise RuntimeError("Module install failed")
# Out:
# Module installed

# %%
from get_opendata import get_data

# %%
from datetime import datetime
datetime.now()
iso_datetime_now = datetime.now().isoformat()
iso_datetime_now = datetime.now().isoformat()
iso_datetime_now
# Out:
# '2026-01-27T01:59:20.274558'

# %%
datetime.now().isoformat()
# Out:
# '2026-01-27T01:58:30.159344'

# %%
data = get_data(endpoint = 'data.cityofnewyork.us', 
                dataset_id = 'rmhc-afj9', 
                datetime_field= 'last_visited',
                start_date = '2026-01-25T00:00:00', 
                end_date = iso_datetime_now, 
                limit = 500000         
)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
# Getting page 1 with offset 0...
# Obtained page 1, records in this page: 500000, total records: 500000
# Sleeping for 5 seconds...
# Getting page 2 with offset 500000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 2 with offset 500000...
# Obtained page 2, records in this page: 500000, total records: 1000000
# Sleeping for 8 seconds...
# Getting page 3 with offset 1000000...
# Obtained page 3, records in this page: 500000, total records: 1500000
# Sleeping for 8 seconds...
# Getting page 4 with offset 1500000...
# Obtained page 4, records in this page: 500000, total records: 2000000
# Sleeping for 9 seconds...
# Getting page 5 with offset 2000000...
# Obtained page 5, records in this page: 500000, total records: 2500000
# Sleeping for 7 seconds...
# Getting page 6 with offset 2500000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 6 with offset 2500000...
# Obtained page 6, records in this page: 500000, total records: 3000000
# Sleeping for 6 seconds...
# Getting page 7 with offset 3000000...
# Obtained page 7, records in this page: 500000, total records: 3500000
# Sleeping for 9 seconds...
# Getting page 8 with offset 3500000...
# Obtained page 8, records in this page: 500000, total records: 4000000
# Sleeping for 5 seconds...
# Getting page 9 with offset 4000000...
# Obtained page 9, records in this page: 500000, total records: 4500000
# Sleeping for 5 seconds...
# Getting page 10 with offset 4500000...
# Obtained page 10, records in this page: 500000, total records: 5000000
# Sleeping for 9 seconds...
# Getting page 11 with offset 5000000...
# Obtained page 11, records in this page: 500000, total records: 5500000
# Sleeping for 7 seconds...
# Getting page 12 with offset 5500000...
# Obtained page 12, records in this page: 500000, total records: 6000000
# Sleeping for 5 seconds...
# Getting page 13 with offset 6000000...
# Obtained page 13, records in this page: 500000, total records: 6500000
# Sleeping for 9 seconds...
# Getting page 14 with offset 6500000...
# Obtained page 14, records in this page: 500000, total records: 7000000
# Sleeping for 7 seconds...
# Getting page 15 with offset 7000000...
# Obtained page 15, records in this page: 500000, total records: 7500000
# Sleeping for 5 seconds...
# Getting page 16 with offset 7500000...
# Obtained page 16, records in this page: 500000, total records: 8000000
# Sleeping for 9 seconds...
# Getting page 17 with offset 8000000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 17 with offset 8000000...
# Obtained page 17, records in this page: 500000, total records: 8500000
# Sleeping for 6 seconds...
# Getting page 18 with offset 8500000...
# Obtained page 18, records in this page: 500000, total records: 9000000
# Sleeping for 9 seconds...
# Getting page 19 with offset 9000000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 19 with offset 9000000...
# Obtained page 19, records in this page: 500000, total records: 9500000
# Sleeping for 8 seconds...
# Getting page 20 with offset 9500000...
# Obtained page 20, records in this page: 500000, total records: 10000000
# Sleeping for 5 seconds...
# Getting page 21 with offset 10000000...
# Obtained page 21, records in this page: 500000, total records: 10500000
# Sleeping for 9 seconds...
# Getting page 22 with offset 10500000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 22 with offset 10500000...
# Obtained page 22, records in this page: 500000, total records: 11000000
# Sleeping for 9 seconds...
# Getting page 23 with offset 11000000...
# Obtained page 23, records in this page: 500000, total records: 11500000
# Sleeping for 6 seconds...
# Getting page 24 with offset 11500000...
# Obtained page 24, records in this page: 500000, total records: 12000000
# Sleeping for 5 seconds...
# Getting page 25 with offset 12000000...
# Obtained page 25, records in this page: 500000, total records: 12500000
# Sleeping for 7 seconds...
# Getting page 26 with offset 12500000...
# Obtained page 26, records in this page: 500000, total records: 13000000
# Sleeping for 10 seconds...
# Getting page 27 with offset 13000000...
# Obtained page 27, records in this page: 500000, total records: 13500000
# Sleeping for 8 seconds...
# Getting page 28 with offset 13500000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 28 with offset 13500000...
# Obtained page 28, records in this page: 500000, total records: 14000000
# Sleeping for 8 seconds...
# Getting page 29 with offset 14000000...
# [Retry 1/3] HTTPSConnectionPool(host='data.cityofnewyork.us', port=443): Read timed out. (read timeout=10)
# Retrying in 5 seconds...
# Getting page 29 with offset 14000000...
# Obtained page 29, records in this page: 500000, total records: 14500000
# Sleeping for 5 seconds...
# Getting page 30 with offset 14500000...
# Obtained page 30, records in this page: 500000, total records: 15000000
# Sleeping for 5 seconds...
# Getting page 31 with offset 15000000...
# Obtained page 31, records in this page: 254367, total records: 15254367
# All data obtained.
# Finished fetching all data!

# %%
len(data)
# Out:
# 15254367

# %%
import os
from pathlib import Path
current_dir = Path.cwd()
data_dir = current_dir.parent / 'raw_data'

os.makedirs(data_dir, exist_ok=True)

# %%
import json

with open(f'{data_dir}/plownyc_raw.json', 'w') as file:
    json.dump(data, file)

# %%
import pandas as pd
from tqdm import tqdm
import gc

chunk_size = 1_000_000
dfs = []

for i in tqdm(range(0, len(data), chunk_size), desc="Chunk-size"):
    chunk = data[i:i + chunk_size]
    df_chunk = pd.DataFrame.from_records(chunk)
    dfs.append(df_chunk)

    del chunk
    gc.collect()

df = pd.concat(dfs, ignore_index=True)

del dfs
gc.collect()
# Out:
# Chunk-size: 100%|██████████| 16/16 [00:08<00:00,  1.93it/s]
# 0

# %%
df.shape
# Out:
# (15254367, 3)

# %%
cleaned_df = df.drop_duplicates(subset=['physical_id', 'last_visited'])
cleaned_df.shape
# Out:
# (3351332, 3)

# %%
# Save cleaned_df into raw_data dir
cleaned_df.to_parquet(f'{data_dir}/plownyc_dropduplicated.parquet', engine='fastparquet')
